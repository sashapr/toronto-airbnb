# %%
from Airbnb import*
from AirbnbClean import*
from ReadWriteFunctions import*
###############################################################################

# %%
df = MergeClean()

# %%
GetAddress()
# Out:
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# Processed address
# 1
# ...

# %%
df = ReadCSVtoDF(pattern = 'csv/airbnb_toronto_with*.csv')

# %%
SaveDFtoCSV('airbnb_toronto_final', df)

# %%
df.shape

# %%
lat = '43.66506'

# %%
long = '-79.38799'

# %%
location_string = lat + ', ' + long

# %%
address = {}
counter = 0

# %%
Address(lat, long)

# %%
address

# %%
SaveDFtoCSV('airbnb_toronto_test_final', df)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df.price)
plt.show()

# %%
df.home_type.value_counts()

# %%
df.listing_type.value_counts()

# %%
df.groupby(['home_type', 'share_type'])['price'].mean()

# %%
#pd.pivot_table(df,index=["num_bedrooms"],columns=["num_beds"], values = [])
pd.crosstab(index=df.price, columns=df.home_type)
